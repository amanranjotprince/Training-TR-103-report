# %% [markdown]
# <a href="https://colab.research.google.com/github/amanranjotprince/Training-TR-103-report/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Conditional Statement**
#
# Conditional Statements are statements in Python that provide a choice for the control flow based on a condition. It means that the control flow of the Python program will be decided based on the outcome of the condition.

# %% [markdown]
# **IN PYTHON, THERE ARE FOUR FORMS OF THE IF.........ELSE STATEMENT**
#
#
# 1.   IF STATEMENT
# 2.   IF...ELSE STATEMENT
# 3.   IF...ELIF STATEMENT
# 4.   IF..ELIF...ELSE STATEMENT
# 5.   NESTED IF

# %%
 #if statement
 #synatx: if condtion: body of if statement
 #rest of the code

# %%
n1 = int(input("Enter a number:"))
if n1 % 2==0:
  print("You have entered an even number")
print("done!")
# Out:
# Enter a number:2
# You have entered an even number
# done!

# %%
age=int(input("enter your age:"))
if age>=18:
  print("you can apply for license")
print("speed thrills but kills")
# Out:
# enter your age:23
# you can apply for license
# speed thrills but kills

# %%
 #if-else statement
 #syntax: if condition1:
 #bodyis executed only if condition is true

# %%
a = int(input("Enter a positive number:"))
if a>0:
  print("Well done!")
else:
  print("Try again.")
# Out:
# Enter a positive number:34
# Well done!

# %%
a = int(input("Enter a positive number:"))
if a>0:
  print("Well done!")
else:
  print("Try again.")
# Out:
# Enter a positive number:25
# Well done!

# %%
age=int(input("enter your age"))
if age>=18:
  print("you can apply for license")
else:
  print("not valid")
# Out:
# enter your age18
# you can apply for license

# %%
#nested-if statement
 #syntax: if Primary Condition:
   #code
   #if secondary condition1:
      #code

# %%
 gpa = float(input("Enter your gpa:"))
if gpa>7.5:
  print("Congratulations!, you are eligible.")
  b = int(input("Enter no. of pending backlogs:"))
  if b==0:
    print("Well done, Go ahead!")
    mat = int(input("Enter your matriculation percentage:"))
    if mat>75:
      print("Just one step more.")
      sec = int(input("Enter you 12th percentage:"))
      if sec>60:
        print("Congratulations! you are in.")
else:
  print("Better luck next time.")
# Out:
# Enter your gpa:568
# Congratulations!, you are eligible.
# Enter no. of pending backlogs:0
# Well done, Go ahead!
# Enter your matriculation percentage:89
# Just one step more.
# Enter you 12th percentage:89
# Congratulations! you are in.

# %%
age=int(input("enter your age"))
own_car='false'
if(age>=18):
  if(own_car=="true"):
    print("drive your car")
  else:
      print("work hard and purchase a new car")
else:
        print("not required")
# Out:
# enter your age56
# work hard and purchase a new car

# %%
 #if-elif-else ladder:
 #syntax:
 #if condition1:
 #execute body if condition 1 is true.
 #elif condition2:
 #......
 #elif condition3:
 #.....
 #else:
 #executed if none of above conditions are satis ed.

# %%
n = int(input("Your marks:"))
if n>=80 and n<=90:
 print("Grade A")
elif n>70 and n<80:
  print("Grade D")
else:
  print("Sorry, you are not qualified.")
# Out:
# Your marks:50
# Sorry, you are not qualified.

# %%
n = int(input("Your marks:"))
if n>80 and n<90:
 print("Grade A")
elif n>70 and n<80:
 print("Grade B")
elif n>60 and n<70:
 print("Grade C")
elif n>50 and n<60:
 print("Grade D")
else:
 print("Sorry, you are not qualified.")
# Out:
# Your marks:56
# Grade D

# %%
age = int(input("Enter your age:"))

if age < 13:
    category = 'Child'
elif age < 20:
    category = 'Teenager'
elif age < 65:
    category = 'Adult'
else:
    category = 'Senior'

print(f"The person is classified as: {category}")
# Out:
# Enter your age:25
# The person is classified as: Adult
